# %% [markdown]
# # 001 print 기초
# 화면에 Hello World 문자열을 출력하세요

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # 002 print 기초
# 화면에 Mary's cosmetics을 출력하세요. (중간에 '가 있음에 주의하세요)

# %%
print("Mary\'s cosmetics")
# Out:
# Mary's cosmetics

# %% [markdown]
# # 003 print 기초
# 화면에 아래 문장을 출력하세요. (중간에 "가 있음에 주의하세요.)

# %%
print("신씨가 소리질렀다. \"도둑이야\".")
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# # 004 print 기초
# 화면에 C:\Windows를 출력하세요.

# %%
print("C:\\Windows")
# Out:
# C:\Windows

# %% [markdown]
# # 005 print 탭과 줄바꿈
# 다음 코드를 실행해보고 \t와 \n의 역할을 설명해보세요.

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
print("\\t는 탭만큼 띄어쓰기 \\n은 줄바꿈이다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.
# \t는 탭만큼 띄어쓰기 \n은 줄바꿈이다.

# %% [markdown]
# # 006 print 여러 데이터 출력
# print 함수에 두 개의 단어를 입력한 예제입니다. 아래 코드의 출력 결과를 예상해봅시다.

# %%
print ("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %% [markdown]
# # 007 print 기초
# print() 함수를 사용하여 다음과 같이 출력하세요.

# %%
print("naver;kakao;sk;samsung")
# 수정
print("naver","kakao","sk","samsung", sep=";")
# Out:
# naver;kakao;sk;samsung
# naver;kakao;sk;samsung

# %% [markdown]
# # 008 print 기초
# print() 함수를 사용하여 다음과 같이 출력하세요.

# %%
print("naver/kakao/sk/samsung")
# Out:
# naver/kakao/sk/samsung

# %% [markdown]
# # 009 print 줄바꿈
# 다음 코드를 수정하여 줄바꿈이 없이 출력하세요. (힌트: end='') print 함수는 두 번 사용합니다. 세미콜론 (;)은 한줄에 여러 개의 명령을 작성하기 위해 사용합니다
# print("first");print("second").

# %%
print(end ="first"), print("second");
# Out:
# firstsecond

# %% [markdown]
# # 010 연산 결과 출력
# 5/3의 결과를 화면에 출력하세요.

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %% [markdown]
# # 011 변수 사용하기
# 삼성전자라는 변수로 50,000원을 바인딩해보세요. 삼성전자 주식 10주를 보유하고 있을 때 총 평가금액을 출력하세요.

# %%
삼성전자 = 50000
print(삼성전자*10)
# Out:
# 500000

# %% [markdown]
# # 012 변수 사용하기
#
# 다음 표는 삼성전자의 일부 투자정보입니다. 변수를 사용해서 시가총액, 현재가, PER 등을 바인딩해보세..79.

# %%
시가총액 = "298조"
현재가 = "50,000원"
PER = 15.79
print ("시가총액:",시가총액+" 현재가: ",현재가+" PER:",PER)
# Out:
# 시가총액: 298조 현재가:  50,000원 PER: 15.79

# %% [markdown]
# # 013 문자열 출력
# 변수 s와 t에는 각각 문자열이 바인딩 되어있습니다! python

# %% [raw]
# >> s = "hello"
# >> t = "python"
# 두 변수를 이용하여 아래와 같이 출력해보세요.
#
# 실행 예:
# hello! python

# %%
s = "hello"
t = "python"

print(s +"!" + t)
# Out:
# hello!python

# %% [markdown]
# # 014 파이썬을 이용한 값 계산
# 아래 코드의 실행 결과를 예상해보세요.

# %% [raw]
# >> 2 + 2 * 3

# %%
8
# Out:
# 8

# %% [markdown]
# # 015 type 함수
# type() 함수는 데이터 타입을 판별합니다. 변수 a에는 128 숫자가 바인딩돼 있어 type 함수가 int (정수)형임을 알려줍니다.

# %% [raw]
# >> a = 128
# >> print (type(a))
# <class 'int'>
#
# 아래 변수에 바인딩된 값의 타입을 판별해보세요.
#
# >> a = "132"

# %%
a = "132"
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# # 016 문자열을 정수로 변환
# 문자열 '720'를 정수형으로 변환해보세요.

# %%
num_str = "720"
num = int(num_str)
print(num)
# Out:
# 720

# %% [markdown]
# # 017 정수를 문자열 100으로 변환
# 정수 100을 문자열 '100'으로 변환해보세요.

# %%
num = 100
num = "100"

# %% [markdown]
# # 018 문자열을 실수로 변환
# 문자열 "15.79"를 실수(float) 타입으로 변환해보세요.

# %%
float = "15.79"
float = 15.79

# %% [markdown]
# # 019 문자열을 정수로 변환
# year라는 변수가 문자열 타입의 연도를 바인딩하고 있습니다. 이를 정수로 변환한 후 최근 3년의 연도를 화면에 출력해보세요.

# %%
year = "2020"
year = 2020

print(year+1, year+2, year+3)
# Out:
# 2021 2022 2023

# %% [markdown]
# # 020 파이썬 계산
# 에이컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에서 판매되고 있습니다. 총 금액은 계산한 후 이를 화면에 출력해보세요. (변수사용하기)

# %%
할부금액 = 48584
할부기간 = 36
총금액 = 할부금액*할부기간
print(총금액)
# Out:
# 1749024

# %% [markdown]
# # 021 문자열 인덱싱
# letters가 바인딩하는 문자열에서 첫번째와 세번째 문자를 출력하세요.

# %% [raw]
# >> letters = 'python'
# 실행 예
# p t

# %%
letters = 'python'
print(letters[0], letters[2])
# Out:
# p t

# %% [markdown]
# # 022 문자열 슬라이싱
# 자동차 번호가 다음과 같을 때 뒤에 4자리만 출력하세요.

# %% [raw]
# >> license_plate = "24가 2210"
# 실행 예: 2210

# %%
license_plate = "24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %% [markdown]
# # 023 문자열 인덱싱
# 아래의 문자열에서 '홀' 만 출력하세요.

# %% [raw]
# >> string = "홀짝홀짝홀짝"
# 실행 예:
# 홀홀홀

# %%
string = "홀짝홀짝홀짝"
print(string[0], string[2], string[4])
# Out:
# 홀 홀 홀

# %%
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %% [markdown]
# # 024 문자열 슬라이싱
# 문자열을 거꾸로 뒤집어 출력하세요.

# %% [raw]
# >> string = "PYTHON"
# 실행 예:
# NOHTYP

# %%
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %% [markdown]
# # 025 문자열 치환
# 아래의 전화번호에서 하이푼 ('-')을 제거하고 출력하세요.

# %% [raw]
# >> phone_number = "010-1111-2222"
# 실행 예
# 010 1111 2222

# %%
phone_number = "010-1111-2222"
print(phone_number.replace("-", " "))
# Out:
# 010 1111 2222

# %% [markdown]
# # 026 문자열 다루기
# 25번 문제의 전화번호를 아래와 같이 모두 붙여 출력하세요.2

# %% [raw]
# 실행 예
# 01011112222

# %%
phone_number = "010-1111-2222"
print(phone_number.replace("-", ""))
# Out:
# 01011112222

# %% [markdown]
# # 027 문자열 다루기
# url 에 저장된 웹 페이지 주소에서 도메인을 출력하세요.

# %% [raw]
# >> url = "http://sharebook.kr"
# 실행 예:
# kr

# %%
url = "http://sharebook.kr"
url_split = (url.split("."))
print(url_split[-1])
# Out:
# kr

# %% [markdown]
# # 028 문자열은 immutable
# 아래 코드의 실행 결과를 예상해보세요.

# %% [raw]
# >> lang = 'python'
# >> lang[0] = 'P'
# >> print(lang)

# %%
lang = 'python'
lang[0] = 'P'
print(lang)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 2
#       1 lang = 'python'
# ----> 2 lang[0] = 'P'
#       3 print(lang)
#
# TypeError: 'str' object does not support item assignment

# %% [raw]
# 문자열은 immutable타입이라 교체 불가

# %% [markdown]
# # 029 replace 메서드
# 아래 문자열에서 소문자 'a'를 대문자 'A'로 변경하세요.

# %% [raw]
# >> string = 'abcdfe2a354a32a'
# 실행 예:
# Abcdfe2A354A32A

# %%
string = 'abcdfe2a354a32a'
print(string.replace("a","A"))
# Out:
# Abcdfe2A354A32A

# %% [markdown]
# # 030 replace 메서드
# 아래 코드의 실행 결과를 예상해보세요.

# %% [raw]
# >> string = 'abcd'
# >> string.replace('b', 'B')
# >> print(string)

# %% [raw]
# abcd 출력
# 실제 string값은 변경되지 않음

# %% [markdown]
# # 031 문자열 합치기
# 아래 코드의 실행 결과를 예상해보세요.

# %% [raw]
# >> a = "3"
# >> b = "4"
# >> print(a + b)

# %%
34 
문자열이기때문에 + 하면 합쳐짐

# %% [markdown]
# # 032 문자열 곱하기
# 아래 코드의 실행 결과를 예상해보세요.

# %% [raw]
# >> print("Hi" * 3)

# %%
HIHIHI 
문자열 3번반복

# %% [markdown]
# # 033 문자열 곱하기
# 화면에 '-'를 80개 출력하세요.

# %%
print("-"*80)
# Out:
# --------------------------------------------------------------------------------

# %% [markdown]
# # 034 문자열 곱하기
# 변수에 다음과 같은 문자열이 바인딩되어 있습니다.

# %% [raw]
# >>> t1 = 'python'
# >>> t2 = 'java'
# 변수에 문자열 더하기와 문자열 곱하기를 사용해서 아래와 같이 출력해보세요.
#
# 실행 예:
# python java python java python java python java

# %%
t1 = 'python'
t2 = 'java'
t3 = t1 +" " + t2 + " "
print(t3*4)
# Out:
# python java python java python java python java

# %% [markdown]
# # 035 문자열 출력
# 변수에 다음과 같이 문자열과 정수가 바인딩되어 있을 때 % formatting을 사용해서 다음과 같이 출력해보세요.

# %% [raw]
# name1 = "김민수"
# age1 = 10
# name2 = "이철희"
# age2 = 13
# #
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
name1 = "김민수" 
age1 = 10
name2 = "이철희"
age2 = 13

print("이름: %s 나이: %d" % (name1, age1))
print("이름: %s 나이: %d" % (name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# # 036 문자열 출력
# 문자열의 format( ) 메서드를 사용해서 035번 문제를 다시 풀어보세요.

# %%
name1 = "김민수" 
age1 = 10
name2 = "이철희"
age2 = 13

print("이름: {} 나이: {}" .format(name1, age1))
print("이름: {} 나이: {}" .format(name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# # 037 문자열 출력
# 파이썬 3.6부터 지원하는 f-string을 사용해서 035번 문제를 다시 풀어보세요.

# %%
name1 = "김민수" 
age1 = 10
name2 = "이철희"
age2 = 13

print(f"이름: {name1} 나이: {age1}")
print(f"이름: {name2} 나이: {age2}")
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# # 038 컴마 제거하기
# 삼성전자의 상장주식수가 다음과 같습니다. 컴마를 제거한 후 이를 정수 타입으로 변환해보세요.

# %% [raw]
# 상장주식수 = "5,969,782,550"

# %%
상장주식수 = "5,969,782,550"
상장주식수 = 상장주식수.replace(",", "")
상장주식수 = int(상장주식수)
print(상장주식수)
# Out:
# 5969782550

# %% [markdown]
# # 039 문자열 슬라이싱
# 다음과 같은 문자열에서 '2020/03'만 출력하세요.

# %% [raw]
# 분기 = "2020/03(E) (IFRS연결)"

# %%
분기 = "2020/03(E) (IFRS연결)"
print(분기[:7])
# Out:
# 2020/03

# %% [markdown]
# # 040 strip 메서드
# 문자열의 좌우의 공백이 있을 때 이를 제거해보세요.

# %% [raw]
# data = "   삼성전자    "

# %%
data = "   삼성전자    "
data.strip()
# Out:
# '삼성전자'

# %% [markdown]
# # 041 upper 메서드
# 다음과 같은 문자열이 있을 때 이를 대문자 BTC_KRW로 변경하세요.

# %% [raw]
# ticker = "btc_krw"

# %%
ticker = "btc_krw"
ticker.upper()
# Out:
# 'BTC_KRW'

# %% [markdown]
# # 042 lower 메서드
# 다음과 같은 문자열이 있을 때 이를 소문자 btc_krw로 변경하세요.

# %% [markdown]
# ticker = "BTC_KRW"

# %%
ticker = "BTC_KRW"
ticker.lower()
# Out:
# 'btc_krw'

# %% [markdown]
# # 043 capitalize 메서드
# 문자열 'hello'가 있을 때 이를 'Hello'로 변경해보세요.

# %%
string = 'hello'
string.capitalize()
# Out:
# 'Hello'

# %% [markdown]
# # 044 endswith 메서드
# 파일 이름이 문자열로 저장되어 있을 때 endswith 메서드를 사용해서 파일 이름이 'xlsx'로 끝나는지 확인해보세요.

# %% [raw]
# file_name = "보고서.xlsx"

# %%
file_name = "보고서.xlsx"
file_name.endswith(".xlsx")
# Out:
# True

# %% [markdown]
# # 045 endswith 메서드
# 파일 이름이 문자열로 저장되어 있을 때 endswith 메서드를 사용해서 파일 이름이 'xlsx' 또는 'xls'로 끝나는지 확인해보세요.

# %% [raw]
# file_name = "보고서.xlsx"

# %%
file_name = "보고서.xlsx"
file_name.endswith(".xlsx") or file_name.endswith(".xls")
# Out:
# True

# %% [markdown]
# # 046 startswith 메서드
# 파일 이름이 문자열로 저장되어 있을 때 startswith 메서드를 사용해서 파일 이름이 '2020'로 시작하는지 확인해보세요.

# %% [raw]
# file_name = "2020_보고서.xlsx"

# %%
file_name = "2020_보고서.xlsx"
file_name.startswith("2020")
# Out:
# True

# %% [markdown]
# # 047 split 메서드
# 다음과 같은 문자열이 있을 때 공백을 기준으로 문자열을 나눠보세요.

# %% [raw]
# a = "hello world"

# %%
a = "hello world"
a.split(" ")
# Out:
# ['hello', 'world']

# %% [markdown]
# # 048 split 메서드
# 다음과 같이 문자열이 있을 때 btc와 krw로 나눠보세요.

# %% [raw]
# ticker = "btc_krw"

# %%
ticker = "btc_krw"
ticker.split("_")
# Out:
# ['btc', 'krw']

# %% [markdown]
# # 049 split 메서드
# 다음과 같이 날짜를 표현하는 문자열이 있을 때 연도, 월, 일로 나눠보세요.

# %% [raw]
# date = "2020-05-01"

# %%
date2 = "2020-05-01"
date2.split("-")
# Out:
# ['2020', '05', '01']

# %% [markdown]
# # 050 rstrip 메서드
# 문자열의 오른쪽에 공백이 있을 때 이를 제거해보세요.

# %% [raw]
# data = "039490     "

# %%
data = "039490     "
data.rstrip()
# Out:
# '039490'

# %% [markdown]
# # 심화문제
# #### 1. 다음 경로의 모든 dll 파일들에 대해 확장자를 제외한 순수 파일 이름을 추출
# >"C:\Windows\System32*.dll
# #### 2. file_data 딕셔너리에 key는 파일 이름, value는 path 값을 갖는 아이템 추가
# > 딕셔너리 구조) file_data[key] = value
# > 예) file_data[file_name] = path # 여기서 file_name은 1)을 통해 추출된 순수 파일 이름임

# %% [raw]
# from glob import glob #파일 경로를 가져오는 라이브러리
# file_data = {} # 딕셔너리 선언
#
# for path in glob("C:\Windows\System32\*.dll"):
#     # file_name = [여기에 알맞는 코드를 작성하여 순수 파일 이름 추출]
#     file_data[filename] = path
#
# for key in file_data.keys():
#     print("[{}]: {}".format(key, file_data[key]))

# %%
from glob import glob #파일 경로를 가져오는 라이브러리
file_data = {} # 딕셔너리 선언

for path in glob("C:\Windows\System32\*.dll"):
    file_name = path.split("\\")[-1]
    result = (file_name.split("."))[0]
    file_data[result] = path

for key in file_data.keys():
    print("[{}]: {}".format(key, file_data[key]))
# Out:
# [69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice]: C:\Windows\System32\69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll
# [6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall]: C:\Windows\System32\6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll
# [aadauthhelper]: C:\Windows\System32\aadauthhelper.dll
# [aadcloudap]: C:\Windows\System32\aadcloudap.dll
# [aadjcsp]: C:\Windows\System32\aadjcsp.dll
# [aadtb]: C:\Windows\System32\aadtb.dll
# [aadWamExtension]: C:\Windows\System32\aadWamExtension.dll
# [AarSvc]: C:\Windows\System32\AarSvc.dll
# [AboutSettingsHandlers]: C:\Windows\System32\AboutSettingsHandlers.dll
# [AboveLockAppHost]: C:\Windows\System32\AboveLockAppHost.dll
# [accessibilitycpl]: C:\Windows\System32\accessibilitycpl.dll
# [accountaccessor]: C:\Windows\System32\accountaccessor.dll
# [AccountsRt]: C:\Windows\System32\AccountsRt.dll
# [AcGenral]: C:\Windows\System32\AcGenral.dll
# [AcLayers]: C:\Windows\System32\AcLayers.dll
# ...

# %%
from glob import glob #파일 경로를 가져오는 라이브러리
file_data = {} # 딕셔너리 선언

for path in glob("C:\Windows\System32\*.dll"):
    file_name = path.split("\\")
    file_data[file_name[-1].split(".")[0]] = path

for key in file_data.keys():
    print("[{}]: {}".format(key, file_data[key]))
# Out:
# [69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice]: C:\Windows\System32\69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll
# [6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall]: C:\Windows\System32\6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll
# [aadauthhelper]: C:\Windows\System32\aadauthhelper.dll
# [aadcloudap]: C:\Windows\System32\aadcloudap.dll
# [aadjcsp]: C:\Windows\System32\aadjcsp.dll
# [aadtb]: C:\Windows\System32\aadtb.dll
# [aadWamExtension]: C:\Windows\System32\aadWamExtension.dll
# [AarSvc]: C:\Windows\System32\AarSvc.dll
# [AboutSettingsHandlers]: C:\Windows\System32\AboutSettingsHandlers.dll
# [AboveLockAppHost]: C:\Windows\System32\AboveLockAppHost.dll
# [accessibilitycpl]: C:\Windows\System32\accessibilitycpl.dll
# [accountaccessor]: C:\Windows\System32\accountaccessor.dll
# [AccountsRt]: C:\Windows\System32\AccountsRt.dll
# [AcGenral]: C:\Windows\System32\AcGenral.dll
# [AcLayers]: C:\Windows\System32\AcLayers.dll
# ...
